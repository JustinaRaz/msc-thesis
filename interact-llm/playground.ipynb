# %%
from pathlib import Path

# %%
folder = Path("/simulated_data/google--gemma-3-12b-it/student_constrained/Lithuanian/B1")
files = [f for f in folder.rglob("*") if f.is_file()]
print("Number of files (recursive):", len(files))
# Out:
# Number of files (recursive): 0
